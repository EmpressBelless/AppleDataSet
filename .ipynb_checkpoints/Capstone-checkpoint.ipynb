# %%
pip install googletrans
# Out:
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
# Collecting chardet==3.*
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting hstspreload
#   Downloading hstspreload-2021.11.1-py3-none-any.whl (1.3 MB)
# Requirement already satisfied: sniffio in c:\users\suzet\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (1.2.0)
# Requirement already satisfied: certifi in c:\users\suzet\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (2020.12.5)
# Requirement already satisfied: idna==2.* in c:\users\suzet\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\suzet\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (1.5.0)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py): started
#   Building wheel for googletrans (setup.py): finished with status 'done'
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15734 sha256=add8daa4fdef8476541fe206094af8df07d838449a677c4c5ceebb98642bd74f
#   Stored in directory: c:\users\suzet\appdata\local\pip\cache\wheels\0e\ce\9b\d51de1064911d42480ab6b57fc943ee36572441f27546354e2
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, h2, h11, httpcore, hstspreload, chardet, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.12.0
#     Uninstalling h11-0.12.0:
#       Successfully uninstalled h11-0.12.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 0.13.7
#     Uninstalling httpcore-0.13.7:
#       Successfully uninstalled httpcore-0.13.7
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.20.0
#     Uninstalling httpx-0.20.0:
#       Successfully uninstalled httpx-0.20.0
# Successfully installed chardet-3.0.4 googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.2.5 requires pyqt5<5.13, which is not installed.
# spyder 4.2.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.

# %%
from googletrans import Translator

# %%
import pandas as pd

# %%
appleset = pd.read_csv('../AppleStore.csv', header = 0)

# %%
appleset
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# 7192                                              Kubik   126644224      USD
# 7193                                  VR Roller-Coaster   120760320      USD
# 7194              Bret Michaels Emojis + Lyric Keyboard   111322112      USD
# 7195          VR Roller Coaster World - Virtual Reality    97235968      USD
# 7196                       Escape the Sweet Shop Series    90898432      USD
#
#       price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0      3.99             21292                26          4.0              4.5
# 1      0.00            161065                26          4.0              3.5
# 2      0.00            188583              2822          3.5              4.5
# 3      0.00            262241               649          4.0              4.5
# 4      0.00            985920              5320          4.5              5.0
# ...     ...               ...               ...          ...              ...
# 7192   0.00               142                75          4.5              4.5
# 7193   0.00                30                30          4.5              4.5
# 7194   1.99                15                 0          4.5              0.0
# 7195   0.00                85                32          4.5              4.5
# 7196   0.00                 3                 3          5.0              5.0
#
#          ver cont_rating   prime_genre  sup_devices.num  ipadSc_urls.num  \
# 0      6.3.5          4+         Games               38                5
# 1      8.2.2          4+  Productivity               37                5
# 2      5.0.0          4+       Weather               37                5
# 3     5.10.0         12+      Shopping               37                5
# 4      7.5.1          4+     Reference               37                5
# ...      ...         ...           ...              ...              ...
# 7192     1.3          4+         Games               38                5
# 7193     0.9          4+         Games               38                0
# 7194   1.0.2          9+     Utilities               37                1
# 7195  1.0.15         12+         Games               38                0
# 7196     1.0          4+         Games               40                0
#
#       lang.num  vpp_lic
# 0           10        1
# 1           23        1
# 2            3        1
# 3            9        1
# 4           45        1
# ...        ...      ...
# 7192         1        1
# 7193         1        1
# 7194         1        1
# 7195         2        1
# 7196         2        1
#
# [7197 rows x 17 columns]

# %%
type(pd.read_csv('../AppleStore.csv'))
print(appleset.shape)
print(appleset.keys())
# Out:
# (7197, 17)
# Index(['Unnamed: 0', 'id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %%
#Top 10 highest priced apps
appleset[['id', 'track_name', 'price']].nlargest(10, 'price')

#simple duplicated row check
appleset.duplicated()

#unique values == True
pd.Series(appleset['id']).is_unique
# Out:
# True

# %%
#Set index to id
appleset = appleset.set_index('id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-441bbdcb1624> in <module>
#       1 #Set index to id
# ----> 2 appleset = appleset.set_index('id')
#       3 appleset
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['id'] are in the columns"

# %%
appleset.head(5)
# Out:
#            Unnamed: 0                                         track_name  \
# id
# 281656475           1                                    PAC-MAN Premium
# 281796108           2                          Evernote - stay organized
# 281940292           3    WeatherBug - Local Weather, Radar, Maps, Alerts
# 282614216           4  eBay: Best App to Buy, Sell, Save! Online Shop...
# 282935706           5                                              Bible
#
#            size_bytes currency  price  rating_count_tot  rating_count_ver  \
# id
# 281656475   100788224      USD   3.99             21292                26
# 281796108   158578688      USD   0.00            161065                26
# 281940292   100524032      USD   0.00            188583              2822
# 282614216   128512000      USD   0.00            262241               649
# 282935706    92774400      USD   0.00            985920              5320
#
#            user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# id
# 281656475          4.0              4.5   6.3.5          4+         Games
# 281796108          4.0              3.5   8.2.2          4+  Productivity
# 281940292          3.5              4.5   5.0.0          4+       Weather
# 282614216          4.0              4.5  5.10.0         12+      Shopping
# 282935706          4.5              5.0   7.5.1          4+     Reference
#
#            sup_devices.num  ipadSc_urls.num  lang.num
# id
# 281656475               38                5        10
# 281796108               37                5        23
# 281940292               37                5         3
# 282614216               37                5         9
# 282935706               37                5        45

# %%
appleset[['track_name','user_rating']].nlargest(20, 'user_rating')
appleset[['track_name', 'user_rating', 'price']].nlargest(20, 'price')
# Out:
#                                                    track_name  user_rating  \
# id
# 551215116                                 LAMP Words For Life          4.0
# 308368164                      Proloquo2Go - Symbol-based AAC          4.0
# 849732663                                         KNFB Reader          4.5
# 320279293                                      NAVIGON Europe          3.5
# 491998279                            Articulation Station Pro          4.5
# 700440156                        Articulation Test Center Pro          4.5
# 946930094    FineScanner Pro - PDF Document Scanner App + OCR          4.0
# 583976519            Cubasis 2 - Mobile Music Creation System          4.0
# 1080310524   VPN Pro | Lifetime Proxy & Best VPN by Betternet          4.5
# 432278816                         プチ・ロワイヤル仏和辞典（第4版）・和仏辞典（第3版）          0.0
# 791077159                                         KORG Gadget          4.5
# 932191687                                         KORG Module          4.0
# 920133658   Anatomy & Physiology: Body Structures and Func...          4.5
# 900404152                                Extreme Landings Pro          4.5
# 934510730                                   Astropad Standard          4.5
# 966030326                                            KORG iM1          4.5
# 1041465860                                           Model 15          5.0
# 1118072618                                  KORG iWAVESTATION          4.5
# 1147432809                                        ARP ODYSSEi          4.5
# 502803489                                    美食杰-让吃饭变简单(VIP版)          4.0
#
#              price
# id
# 551215116   299.99
# 308368164   249.99
# 849732663    99.99
# 320279293    74.99
# 491998279    59.99
# 700440156    59.99
# 946930094    59.99
# 583976519    49.99
# 1080310524   49.99
# 432278816    47.99
# 791077159    39.99
# 932191687    39.99
# 920133658    34.99
# 900404152    29.99
# 934510730    29.99
# 966030326    29.99
# 1041465860   29.99
# 1118072618   29.99
# 1147432809   29.99
# 502803489    27.99

# %%
#Genre categories
appleset['prime_genre'].unique()
len(appleset['prime_genre'].unique())
# Out:
# 23

# %%
appleset

# %%
#Highest priced app for each genre
appleset[['id','prime_genre']].groupby('prime_genre').count()

#highestprice for each genre. 
appleset.groupby('prime_genre').max('price')
appleset[['prime_genre', 'track_name','price']].groupby('prime_genre').max()

#Doublechecking 
# eachcat = appleset[['id','prime_genre','price']].sort_values(['prime_genre','price'], ascending=False)
# appleset[['id','prime_genre','price']][eachcat['prime_genre']  == 'Education'].set_index('id').sort_values('price', ascending=False)
# Out:
#                                        track_name   price
# prime_genre
# Book                 銀魂 公式連載アプリ〜銀魂の漫画が毎週１巻読めるアプリ〜   27.99
# Business           애드픽 - 인플루언서가 되어 의미있는 수익을 올리세요!   59.99
# Catalogs              女の子のための女子トレンドまとめアプリ-ウーマガジン-    7.99
# Education                  驾校一点通-保过版，2017最新驾考学车宝典  299.99
# Entertainment                     龙珠直播-高清游戏娱乐直播平台    9.99
# Finance                           黄金日-贵金属理财投资黄金白银    5.99
# Food & Drink                 香哈菜谱-最专业的家常菜谱大全 无广告版   27.99
# Games                                         ｗｗｗ   29.99
# Health & Fitness                        闪瘦-健康减肥瘦身    9.99
# Lifestyle                   驾考宝典-2017最新考驾照驾校学车驾考通    4.99
# Medical                           平安好医生-要健康上平安好医生   34.99
# Music                  radio.de - Der Radioplayer   49.99
# Navigation                        高德地图（精准专业的手机地图）   74.99
# News                            ２ちゃんねる for iPhone    3.99
# Photo & Video        誰にもバレない！[秘密のアルバム]　無料で写真をロック！   22.99
# Productivity                   腾讯微云HD-安全备份共享文件和照片   99.99
# Reference                            花しらべ 花認識/花検索   47.99
# Shopping                     零钱夺宝pro-新手99元红包助你1元购    1.99
# Social Networking               非诚勿扰-中国最大免费婚恋交友平台    9.99
# Sports                    豪快ショット連発！爽快卓球ゲーム「サァァァ！」   19.99
# Travel                       驴妈妈旅游-订景点门票机票火车票特价酒店    9.99
# Utilities                            高清影视-大片免费天天看   24.99
# Weather                                    실시간 날씨    9.99

# %%
#Verify the language of my track_names


# for i in appleset['track_name']:
#     translator = Translator()
#     response = translator.translate(i)
#     print(response)
# 
# for y in appleset['language']:
#     print(response)
    
# print(appleset['language'])

# %%
appleset.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0          4.0              4.5   6.3.5          4+         Games
# 1          4.0              3.5   8.2.2          4+  Productivity
# 2          3.5              4.5   5.0.0          4+       Weather
# 3          4.0              4.5  5.10.0         12+      Shopping
# 4          4.5              5.0   7.5.1          4+     Reference
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38                5        10        1
# 1               37                5        23        1
# 2               37                5         3        1
# 3               37                5         9        1
# 4               37                5        45        1

# %%
applesetdetails = pd.read_csv('../AppleStore_description.csv', header = 0)

# %%
applesetdetails
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# ...          ...                                                ...
# 7192  1187617475                                              Kubik
# 7193  1187682390                                  VR Roller-Coaster
# 7194  1187779532              Bret Michaels Emojis + Lyric Keyboard
# 7195  1187838770          VR Roller Coaster World - Virtual Reality
# 7196  1188375727                       Escape the Sweet Shop Series
#
#       size_bytes                                           app_desc
# 0      100788224  SAVE 20%, now only $3.99 for a limited time!\n...
# 1      158578688  Let Evernote change the way you organize your ...
# 2      100524032  Download the most popular free weather app pow...
# 3      128512000  The eBay app is the best way to find anything ...
# 4       92774400  On more than 250 million devices around the wo...
# ...          ...                                                ...
# 7192   126644224  Place the falling blocks correctly in order to...
# 7193   120760320  A thrilling virtual reality roller coaster exp...
# 7194   111322112  Rock star Bret Michaels, winner of Celebrity A...
# 7195    97235968  VR Roller Coaster World is an app for Google C...
# 7196    90898432  5 previous escape games plus 1 new game in one...
#
# [7197 rows x 4 columns]

# %%
applesetdetails['app_desc']
# Out:
# 0       SAVE 20%, now only $3.99 for a limited time!\n...
# 1       Let Evernote change the way you organize your ...
# 2       Download the most popular free weather app pow...
# 3       The eBay app is the best way to find anything ...
# 4       On more than 250 million devices around the wo...
#                               ...
# 7192    Place the falling blocks correctly in order to...
# 7193    A thrilling virtual reality roller coaster exp...
# 7194    Rock star Bret Michaels, winner of Celebrity A...
# 7195    VR Roller Coaster World is an app for Google C...
# 7196    5 previous escape games plus 1 new game in one...
# Name: app_desc, Length: 7197, dtype: object
