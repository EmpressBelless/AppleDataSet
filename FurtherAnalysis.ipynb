# %% [markdown]
# # Further Research - Conditional Filtering

# %%
import pandas as pd
from googletrans import Translator
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import dataframe_image as dfi

# %%
appleset = pd.read_csv('../AppleStore.csv', header = 0)

# %% [markdown]
# ##### Top 20 Highest priced apps

# %%
#Top 20 highest priced apps
Highest_priced = appleset[['prime_genre', 'user_rating','track_name', 'price']].nlargest(20, 'price')
Highest_priced
# Out:
#        prime_genre  user_rating  \
# 1479     Education          4.0
# 115      Education          4.0
# 2568  Productivity          4.5
# 162     Navigation          3.5
# 1136     Education          4.5
# 2181     Education          4.5
# 3238      Business          4.0
# 1688         Music          4.0
# 5340      Business          4.5
# 778      Reference          0.0
# 2405         Music          4.5
# 3093         Music          4.0
# 3012       Medical          4.5
# 2833         Games          4.5
# 3125  Productivity          4.5
# 3457         Music          4.5
# 4391         Music          5.0
# 6215         Music          4.5
# 6784         Music          4.5
# 1188  Food & Drink          4.0
#
#                                              track_name   price
# 1479                                LAMP Words For Life  299.99
# 115                      Proloquo2Go - Symbol-based AAC  249.99
# 2568                                        KNFB Reader   99.99
# 162                                      NAVIGON Europe   74.99
# 1136                           Articulation Station Pro   59.99
# 2181                       Articulation Test Center Pro   59.99
# 3238   FineScanner Pro - PDF Document Scanner App + OCR   59.99
# 1688           Cubasis 2 - Mobile Music Creation System   49.99
# 5340   VPN Pro | Lifetime Proxy & Best VPN by Betternet   49.99
# 778                         プチ・ロワイヤル仏和辞典（第4版）・和仏辞典（第3版）   47.99
# 2405                                        KORG Gadget   39.99
# 3093                                        KORG Module   39.99
# 3012  Anatomy & Physiology: Body Structures and Func...   34.99
# 2833                               Extreme Landings Pro   29.99
# 3125                                  Astropad Standard   29.99
# 3457                                           KORG iM1   29.99
# 4391                                           Model 15   29.99
# 6215                                  KORG iWAVESTATION   29.99
# 6784                                        ARP ODYSSEi   29.99
# 1188                                   美食杰-让吃饭变简单(VIP版)   27.99

# %% [markdown]
# ### Top free apps

# %%
#Top 10 free apps + highest rating count total + user rating == 5.0
appleset[(appleset['price'] == 0.00) & (appleset['user_rating'] == 5.0)].sort_values('rating_count_tot', ascending=False).nlargest(10, 'rating_count_tot')
# Out:
#       Unnamed: 0         id  \
# 1104        1289  487119327
# 3086        3694  930574573
# 2177        2537  698255242
# 810          922  436491861
# 2731        3254  887947640
# 1802        2093  600674056
# 1817        2111  606190854
# 1918        2230  635573390
# 467          532  381471023
# 884         1010  448639966
#
#                                              track_name  size_bytes currency  \
# 1104                                        Head Soccer   121319424      USD
# 3086         Sniper 3D Assassin: Shoot to Kill Gun Game   157851648      USD
# 2177                                 Geometry Dash Lite    69076992      USD
# 810                                  Domino's Pizza USA   105743360      USD
# 2731                                       CSR Racing 2  1944321024      USD
# 1802  Pictoword: Fun 2 Pics Guess What's the Word Tr...   126216192      USD
# 1817                                         Iron Force   124666880      USD
# 1918                 Sniper Shooter: Gun Shooting Games   113509376      USD
# 467                                        Flashlight Ⓞ    42027008      USD
# 884   Pic Collage - Picture Editor & Photo Collage M...   109210624      USD
#
#       price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 1104    0.0            481564              8518          5.0              5.0
# 3086    0.0            386521             10332          5.0              5.0
# 2177    0.0            370370              2650          5.0              4.5
# 810     0.0            258624              2481          5.0              4.5
# 2731    0.0            257100              2025          5.0              5.0
# 1802    0.0            186089              1010          5.0              4.5
# 1817    0.0            141634              1655          5.0              4.0
# 1918    0.0            134080               451          5.0              5.0
# 467     0.0            130450              1010          5.0              4.5
# 884     0.0            123433              1521          5.0              5.0
#
#           ver cont_rating    prime_genre  sup_devices.num  ipadSc_urls.num  \
# 1104    5.4.1          4+          Games               40                4
# 3086   1.17.6         17+          Games               40                5
# 2177     2.11          4+          Games               37                4
# 810     4.2.0          4+   Food & Drink               37                5
# 2731   1.11.3          4+          Games               37                5
# 1802    2.4.2          4+          Games               37                5
# 1817    2.4.1         17+          Games               38                5
# 1918    5.0.4         12+          Games               37                5
# 467     2.1.2          4+      Utilities               40                0
# 884   7.12.17         12+  Photo & Video               37                5
#
#       lang.num  vpp_lic
# 1104        11        1
# 3086         9        1
# 2177         1        1
# 810          2        1
# 2731        11        1
# 1802         1        1
# 1817        12        1
# 1918         1        1
# 467         22        1
# 884         12        1

# %% [markdown]
# #### Top 10 free apps, 5 star user rating, sorted by rating count total, grouped by genre

# %%
genre_free = appleset[(appleset['price'] == 0.00) & (appleset['user_rating'] == 5.0)].sort_values('rating_count_tot', ascending=False).nlargest(10, 'rating_count_tot')
genre_free.groupby('prime_genre').count()['id']
# Out:
# prime_genre
# Food & Drink     1
# Games            7
# Photo & Video    1
# Utilities        1
# Name: id, dtype: int64

# %% [markdown]
# #### Top 100 free apps, 5star user_rating, sorted by rating count total

# %%
genre_free_100 = appleset[(appleset['price'] == 0.00) & (appleset['user_rating'] == 5.0)].sort_values('rating_count_tot', ascending=False).nlargest(100, 'rating_count_tot')
genre_free_100
# Out:
#       Unnamed: 0          id  \
# 1104        1289   487119327
# 3086        3694   930574573
# 2177        2537   698255242
# 810          922   436491861
# 2731        3254   887947640
# ...          ...         ...
# 6455        9388  1130610367
# 6399        9256  1126835894
# 3798        4660   995014054
# 2665        3171   876336838
# 3766        4617   992421775
#
#                                              track_name  size_bytes currency  \
# 1104                                        Head Soccer   121319424      USD
# 3086         Sniper 3D Assassin: Shoot to Kill Gun Game   157851648      USD
# 2177                                 Geometry Dash Lite    69076992      USD
# 810                                  Domino's Pizza USA   105743360      USD
# 2731                                       CSR Racing 2  1944321024      USD
# ...                                                 ...         ...      ...
# 6455                                       Donut Dazzle    65595392      USD
# 6399    Epic Jackpot Slots: Slot Machines & Bonus Games   181364736      USD
# 3798                                          Pinchworm   100635648      USD
# 2665                             喜马拉雅FM（听书社区）电台有声小说相声英语   130731008      USD
# 3766  Patternator Pattern Maker Backgrounds & Wallpa...    47943680      USD
#
#       price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 1104    0.0            481564              8518          5.0              5.0
# 3086    0.0            386521             10332          5.0              5.0
# 2177    0.0            370370              2650          5.0              4.5
# 810     0.0            258624              2481          5.0              4.5
# 2731    0.0            257100              2025          5.0              5.0
# ...     ...               ...               ...          ...              ...
# 6455    0.0              2317               102          5.0              4.5
# 6399    0.0              2291               116          5.0              5.0
# 3798    0.0              2288                74          5.0              5.0
# 2665    0.0              2111                 0          5.0              0.0
# 3766    0.0              2092               625          5.0              5.0
#
#          ver cont_rating    prime_genre  sup_devices.num  ipadSc_urls.num  \
# 1104   5.4.1          4+          Games               40                4
# 3086  1.17.6         17+          Games               40                5
# 2177    2.11          4+          Games               37                4
# 810    4.2.0          4+   Food & Drink               37                5
# 2731  1.11.3          4+          Games               37                5
# ...      ...         ...            ...              ...              ...
# 6455     1.3          4+          Games               37                0
# 6399   1.111         12+          Games               40                5
# 3798   1.0.5          4+          Games               37                5
# 2665   6.3.6         12+           Book               37                5
# 3766     2.1          4+  Photo & Video               37                5
#
#       lang.num  vpp_lic
# 1104        11        1
# 3086         9        1
# 2177         1        1
# 810          2        1
# 2731        11        1
# ...        ...      ...
# 6455         1        1
# 6399        10        1
# 3798        11        1
# 2665         2        1
# 3766        12        1
#
# [100 rows x 17 columns]

# %%
genre_free_100_chart = genre_free_100.groupby('prime_genre').count()['id']
genre_free_100_chart
# Out:
# prime_genre
# Book                  2
# Catalogs              1
# Education             3
# Entertainment         3
# Finance               1
# Food & Drink          1
# Games                52
# Health & Fitness      8
# Lifestyle             1
# News                  1
# Photo & Video        13
# Productivity          2
# Shopping              8
# Social Networking     1
# Utilities             3
# Name: id, dtype: int64

# %% [markdown]
# #### Number of supporting devices with free apps

# %% [markdown]
# ###### What is the correlation of number of supporting devices and high rating score?

# %%
# What is the mean of supporting devices for top 100
mean_supp = appleset[(appleset['price'] == 0.00) & (appleset['user_rating'] == 5.0)].sort_values('rating_count_tot', ascending=False).nlargest(100, 'rating_count_tot')
mean_supp
mean_supp['sup_devices.num'].mean()
#result 37.71
# Out:
# 37.71

# %% [markdown]
# ##### Top 10 paid apps, highest rating count total and user rating at 5.0

# %%
appleset[(appleset['price'] > 0.00) & (appleset['user_rating'] == 5.0)].sort_values('rating_count_tot', ascending=False).nlargest(10, 'rating_count_tot')
# Out:
#       Unnamed: 0         id  \
# 302          341  350642635
# 498          568  387428400
# 1877        2180  625334537
# 350          396  363282253
# 1484        1721  552039496
# 970         1118  466710109
# 1191        1388  503092422
# 2064        2398  667362389
# 1588        1842  567767430
# 271          305  342548956
#
#                                              track_name  size_bytes currency  \
# 302                                  Plants vs. Zombies   105379840      USD
# 498                                      Infinity Blade   624107810      USD
# 1877                                      Geometry Dash    83931136      USD
# 350                               Plants vs. Zombies HD   225859584      USD
# 1484                                           The Room   338273280      USD
# 970                                            HB2 PLUS    56817664      USD
# 1191                                         Ski Safari   161255424      USD
# 2064                                       The Room Two   460077056      USD
# 1588                                        Yoga Studio   162386944      USD
# 271   TurboScan™ Pro - document & receipt scanner: s...     8821760      USD
#
#       price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 302    0.99            426463               680          5.0              4.0
# 498    0.99            326482            177050          5.0              5.0
# 1877   1.99            266440              6263          5.0              4.5
# 350    0.99            163598               503          5.0              4.0
# 1484   0.99            143908              1056          5.0              5.0
# 970    0.99             54073                73          5.0              4.0
# 1191   0.99             45121              1168          5.0              4.5
# 2064   1.99             36809              2858          5.0              5.0
# 1588   4.99             28439              1067          5.0              5.0
# 271    4.99             28388              7009          5.0              5.0
#
#          ver cont_rating       prime_genre  sup_devices.num  ipadSc_urls.num  \
# 302   1.9.13          9+             Games               38                0
# 498    1.4.1         12+             Games               43                5
# 1877    2.10          4+             Games               37                4
# 350   1.9.12          9+             Games               24                5
# 1484   1.0.4          9+             Games               24                5
# 970    1.3.0          4+             Games               38                5
# 1191   1.5.4          4+             Games               40                5
# 2064   1.0.4          9+             Games               39                4
# 1588     3.4          4+  Health & Fitness               37                5
# 271    2.8.2          4+          Business               38                5
#
#       lang.num  vpp_lic
# 302          5        1
# 498         13        1
# 1877         1        1
# 350          5        1
# 1484         1        1
# 970          4        1
# 1191         1        1
# 2064         1        1
# 1588         1        1
# 271          9        1

# %%
#^What are the top 10 genres
genre_paid = appleset[(appleset['price'] > 0.00) & (appleset['user_rating'] == 5.0)].sort_values('rating_count_tot', ascending=False).nlargest(10, 'rating_count_tot')
genre_paid
genre_paid.groupby('prime_genre').count()['id']
# Out:
# prime_genre
# Business            1
# Games               8
# Health & Fitness    1
# Name: id, dtype: int64

# %% [markdown]
# #### Top 100 paid apps, 5 star user rating, sorted by rating count

# %%
# #^What are the top 100 genres, not sorted
genre_paid = appleset[(appleset['price'] > 0.00) & (appleset['user_rating'] == 5.0)].sort_values('rating_count_tot', ascending=False).nlargest(100, 'rating_count_tot')
genre_paid
# Out:
#       Unnamed: 0          id                                       track_name  \
# 302          341   350642635                               Plants vs. Zombies
# 498          568   387428400                                   Infinity Blade
# 1877        2180   625334537                                    Geometry Dash
# 350          396   363282253                            Plants vs. Zombies HD
# 1484        1721   552039496                                         The Room
# ...          ...         ...                                              ...
# 3579        4353   976690555                        Patterning : Drum Machine
# 4101        5105  1022268606                                     Beat da Beat
# 2081        2421   671123035                                      Burger Shop
# 4391        5555  1041465860                                         Model 15
# 1347        1562   529646208  Frax HD - The First Realtime Immersive Fractals
#
#       size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 302    105379840      USD   0.99            426463               680
# 498    624107810      USD   0.99            326482            177050
# 1877    83931136      USD   1.99            266440              6263
# 350    225859584      USD   0.99            163598               503
# 1484   338273280      USD   0.99            143908              1056
# ...          ...      ...    ...               ...               ...
# 3579   134340608      USD   9.99               306                21
# 4101   262926336      USD   0.99               301               180
# 2081    25294848      USD   0.99               299                18
# 4391   205972480      USD  29.99               298                35
# 1347    94023680      USD   1.99               298                20
#
#       user_rating  user_rating_ver     ver cont_rating    prime_genre  \
# 302           5.0              4.0  1.9.13          9+          Games
# 498           5.0              5.0   1.4.1         12+          Games
# 1877          5.0              4.5    2.10          4+          Games
# 350           5.0              4.0  1.9.12          9+          Games
# 1484          5.0              5.0   1.0.4          9+          Games
# ...           ...              ...     ...         ...            ...
# 3579          5.0              5.0   1.2.3          4+          Music
# 4101          5.0              5.0     1.3          9+          Games
# 2081          5.0              5.0     1.2          4+          Games
# 4391          5.0              5.0   1.1.1          4+          Music
# 1347          5.0              5.0   1.4.2          4+  Entertainment
#
#       sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 302                38                0         5        1
# 498                43                5        13        1
# 1877               37                4         1        1
# 350                24                5         5        1
# 1484               24                5         1        1
# ...               ...              ...       ...      ...
# 3579               24                5         8        1
# 4101               40                4         1        1
# 2081               40                0        12        1
# 4391               25                5         1        1
# 1347               24                5         8        1
#
# [100 rows x 17 columns]

# %% [markdown]
# ##### Count of the top 100 genres

# %%
genre_paid[['id','prime_genre']].groupby('prime_genre').count()
# Out:
#                   id
# prime_genre
# Business           2
# Education          1
# Entertainment      2
# Food & Drink       4
# Games             59
# Health & Fitness   9
# Lifestyle          3
# Music              3
# Photo & Video      3
# Productivity       4
# Reference          5
# Sports             1
# Utilities          2
# Weather            2

# %% [markdown]
# ####  Top 100 paid apps, average # supporting_devices

# %%
mean_paid_Supp = appleset[(appleset['price'] > 0.00) & (appleset['user_rating'] == 5.0)].sort_values('rating_count_tot', ascending=False).nlargest(100, 'rating_count_tot')
mean_paid_Supp
mean_paid_Supp['sup_devices.num'].mean()
#36.94
# Out:
# 36.94
